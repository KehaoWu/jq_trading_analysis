# %%
# gt = get_backtest("301cc2a40a90f04d20876c8a0ee37cc7")
gt = get_backtest("1bd0701b75e2b680a5bd1dbfd34a8b07")

# %%
print(dir(gt))
# Out:
# ['_Backtest__request_json', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_check_parent_orders_permission', 'backtest_id', 'get_balances', 'get_orders', 'get_params', 'get_parent_orders', 'get_period_risks', 'get_positions', 'get_records', 'get_results', 'get_risk', 'get_status', 'parse_date_params']

# %%
help(gt.get_positions)
# Out:
# Help on method get_positions in module jqresearch.base:
#
# get_positions(start_date=None, end_date=None, pindex=None) method of jqresearch.base.Backtest instance
#     所有持仓列表
#
#     Args:
#         start_date: 数据起始日，需要与end_date一起使用，不指定时，默认查全部
#         end_date: 数据结束日，需要与start_date一起使用，不指定时，默认查全部
#         pindex: 整数，对应策略中的pindex，用于获取指定pindex子账户对应的持仓，不指定时，查询整个策略
#
#
#     Returns: list of dict, dict keys:
#         time: 时间
#         security: 证券代码
#         security_name: 证券名称
#         amount: 持仓数量
#         price: 股票价格
#         avg_cost: 买入股票平均每股所花的钱
#         closeable_amount: 可平仓数量
#
#     如果没有持仓则返回一个空的 list.

# %%
overview = gt.get_results()
print(overview[0], overview[-1])
# Out:
# {'benchmark_returns': 0.04166688150642184, 'returns': 0.0, 'time': '2009-01-05 16:00:00'} {'benchmark_returns': 2.17686567702881, 'returns': 4.588198932557023, 'time': '2025-07-21 16:00:00'}

# %%
from datetime import datetime
start_date = datetime.strptime(overview[0]['time'][:10], '%Y-%m-%d')
end_date = datetime.strptime(overview[1]['time'][:10], '%Y-%m-%d')
print(start_date)
positions = gt.get_positions(start_date=start_date, end_date=end_date)
print(positions)
# Out:
# 2009-01-05 00:00:00
# ...

# %%
orders = gt.get_orders(start_date=start_date, end_date=end_date)
print(orders)
# Out:
# [{'time': '2009-01-06 09:30:00', 'gains': 0.0, 'cancel_time': None, 'pindex': 0, 'match_time': '2009-01-06 09:30:00', 'limit_price': 0, 'commission': 27.12, 'price': 9.1, 'type': 'market', 'finish_time': '2009-01-06 09:30:00', 'entrust_time': '2009-01-06 09:30:00', 'action': 'open', 'side': 'long', 'comment': '', 'security_name': '长江证券', 'security': '000783.XSHE', 'filled': 29800, 'amount': 29800, 'status': 'done'}, {'time': '2009-01-06 09:30:00', 'gains': 0.0, 'cancel_time': None, 'pindex': 0, 'match_time': '2009-01-06 09:30:00', 'limit_price': 0, 'commission': 27.16, 'price': 6.56, 'type': 'market', 'finish_time': '2009-01-06 09:30:00', 'entrust_time': '2009-01-06 09:30:00', 'action': 'open', 'side': 'long', 'comment': '', 'security_name': '吉林制药', 'security': '000545.XSHE', 'filled': 41400, 'amount': 41400, 'status': 'done'}, {'time': '2009-01-06 09:30:00', 'gains': 0.0, 'cancel_time': None, 'pindex': 0, 'match_time': '2009-01-06 09:30:00', 'limit_price': 0, 'commission': 27.14, 'p
# ...
